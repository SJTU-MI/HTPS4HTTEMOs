# %%
# import package

from xenonpy.datatools import preset
from xenonpy.descriptor import Compositions
from xenonpy.datatools import preset

# %%
# download the data from Materials Project by KEY
# please use your own key
preset.build('mp_samples', api_key='Please use your own API key of MP')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:07<00:00,  1.63it/s]

# %%
# get compositional descriptors

cal = Compositions()
samples = preset.mp_samples
comps = samples['composition']
com_descriptor = cal.transform(comps)

# %%
com_descriptor
# Out:
#             ave:atomic_number  ave:atomic_radius  ave:atomic_radius_rahm  \
# mp-708                   45.0         163.000000                   257.5
# mp-749                   34.5         136.500000                   229.5
# mp-830                   19.0         116.500000                   206.0
# mp-866291                41.0         150.777654                   222.0
# mp-938                   42.0         148.500000                   238.0
# ...                       ...                ...                     ...
# mp-1009540               41.0         113.000000                   217.0
# mp-1009639               33.0         137.000000                   232.5
# mp-1009746               18.0         145.000000                   243.0
# mp-1009750               14.0         127.000000                   221.0
# mp-1002124               39.0         129.000000                   227.0
#
#             ave:atomic_volume  ave:atomic_weight  ave:boiling_point  \
# ...

# %%
com_descriptor.to_csv(r'.\2_Xenonpy_features.csv')
